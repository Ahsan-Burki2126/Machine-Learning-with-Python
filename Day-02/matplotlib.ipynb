# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import sys

# %%
data = pd.read_csv("../data.csv")
plt.scatter(data["Population"],data["Profit"],marker="x",color="red")

plt.xlable( "Population")
plt.ylable("Profit")
plt.title("Population vs Profit")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 data = pd.read_csv("../data.csv")
#       2 plt.scatter(data["Population"],data["Profit"],marker="x",color="red")
# ----> 4 plt.xlable( "Population")
#       5 plt.ylable("Profit")
#       6 plt.title("Population vs Profit")
#
# TypeError: 'str' object is not callable
